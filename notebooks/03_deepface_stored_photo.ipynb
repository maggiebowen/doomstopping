# %% [markdown]
# # DeepFace Detecting Emotions
#
# Testing DeepFace on already-taken photos

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
import json
import numpy as np

# %%
img_path = "../data/images/jonas-happy.jpg"
img = cv2.imread(img_path)
plt.imshow(img[:, :, ::-1]) # because OpenCV uses BGR (inverted colors)

# %%
demography = DeepFace.analyze(img_path, actions=["emotion", "age", "gender", "race"])
demography
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.78it/s]
# [{'emotion': {'angry': np.float32(0.013720465),
#    'disgust': np.float32(0.64612395),
#    'fear': np.float32(7.806168),
#    'happy': np.float32(24.511463),
#    'sad': np.float32(3.277546),
#    'surprise': np.float32(0.00025144918),
#    'neutral': np.float32(63.744728)},
#   'dominant_emotion': 'neutral',
#   'region': {'x': 427,
#    'y': 147,
#    'w': 370,
#    'h': 370,
#    'left_eye': (673, 313),
#    'right_eye': (553, 306)},
#   'face_confidence': 0.96,
#   'age': 24,
#   'gender': {'Woman': np.float32(0.26051968), 'Man': np.float32(99.73948)},
#   'dominant_gender': 'Man',
#   'race': {'asian': np.float32(1.7243904),
#    'indian': np.float32(5.220358),
#    'black': np.float32(0.30755335),
#    'white': np.float32(39.659733),
#    'middle eastern': np.float32(29.302942),
#    'latino hispanic': np.float32(23.785028)},
#   'dominant_race': 'white'}]

# %%
print(f"DeepFace detected {len(demography)} face(s)")
# Out:
# DeepFace detected 1 face(s)

# %%
face = demography[0]

print(face['dominant_emotion'])
# Out:
# neutral
